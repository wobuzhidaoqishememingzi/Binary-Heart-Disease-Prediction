# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cm = np.array([[73,9],
               [14,88]])

plt.figure()

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=['Predicted 0','Predicted 1'],
            yticklabels=['Actual 0','Actual 1'])

plt.title("Logistica Regression-Confusion Matrix")
plt.ylabel("Actual")
plt.xlabel("Predicted")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cm = np.array([[69,13],
               [17,85]])

plt.figure()

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=['Predicted 0','Predicted 1'],
            yticklabels=['Actual 0','Actual 1'])

plt.title("Decision Tree-Confusion Matrix")
plt.ylabel("Actual")
plt.xlabel("Predicted")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cm = np.array([[72,10],
               [10,92]])

plt.figure()

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=['Predicted 0','Predicted 1'],
            yticklabels=['Actual 0','Actual 1'])

plt.title("Random Forest-Confusion Matrix")
plt.ylabel("Actual")
plt.xlabel("Predicted")

plt.show()
